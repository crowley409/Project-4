# %%
import pandas as pd
from scipy.stats import ttest_ind
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('clean_brain_tumor.csv')
df
# Out:
#       Class       Mean     Variance  Standard Deviation   Entropy  Skewness  \
# 0         0   6.535339   619.587845           24.891522  0.109059  4.276477
# 1         0   8.749969   805.957634           28.389393  0.266538  3.718116
# 2         1   7.341095  1143.808219           33.820234  0.001467  5.061750
# 3         1   5.958145   959.711985           30.979219  0.001477  5.677977
# 4         0   7.315231   729.540579           27.010009  0.146761  4.283221
# ...     ...        ...          ...                 ...       ...       ...
# 3757      0  21.234512  1208.850174           34.768523  0.063774  2.082079
# 3758      0  20.435349  1227.151440           35.030721  0.066763  2.144625
# 3759      0  18.011520  1151.582765           33.934978  0.068396  2.308349
# 3760      0  13.330429   945.732779           30.752769  0.087872  2.732822
# 3761      0   6.110138   480.884025           21.929068  0.118171  4.110669
#
# ...

# %%
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(corr_matrix,
            annot=True,
            linewidths=0.5,
            fmt=".2f")
# Out:
# <Axes: >

# %%
group_0 = df[df['Class'] == 0]['Mean']
group_1 = df[df['Class'] == 1]['Mean']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 9.982183833486934
#
# Group 1:
# 8.87952686475277
#
# T-Test Results:
# T-Statistic: 5.897080375831912
# P-Value: 4.025986197723042e-09

# %%
group_0 = df[df['Class'] == 0]['Variance']
group_1 = df[df['Class'] == 1]['Variance']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 581.2304422839013
#
# Group 1:
# 871.5294771553329
#
# T-Test Results:
# T-Statistic: -19.90953389298961
# P-Value: 6.167900195923382e-84

# %%
group_0 = df[df['Class'] == 0]['Standard Deviation']
group_1 = df[df['Class'] == 1]['Standard Deviation']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 22.928335675375948
#
# Group 1:
# 27.966543822733552
#
# T-Test Results:
# T-Statistic: -18.27158352176896
# P-Value: 1.5932787480335406e-71

# %%
group_0 = df[df['Class'] == 0]['Entropy']
group_1 = df[df['Class'] == 1]['Entropy']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 0.1227951463612008
#
# Group 1:
# 0.012835374895904987
#
# T-Test Results:
# T-Statistic: 75.97769371778978
# P-Value: 0.0

# %%
group_0 = df[df['Class'] == 0]['Skewness']
group_1 = df[df['Class'] == 1]['Skewness']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 3.175090332036205
#
# Group 1:
# 5.248630877434311
#
# T-Test Results:
# T-Statistic: -26.972736524981716
# P-Value: 1.2256704561450246e-146

# %%
group_0 = df[df['Class'] == 0]['Kurtosis']
group_1 = df[df['Class'] == 1]['Kurtosis']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 12.212278245361583
#
# Group 1:
# 39.430991860025706
#
# T-Test Results:
# T-Statistic: -15.149151693190294
# P-Value: 2.288749547054501e-50

# %%
group_0 = df[df['Class'] == 0]['Contrast']
group_1 = df[df['Class'] == 1]['Contrast']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 107.01448233182137
#
# Group 1:
# 153.83713630279723
#
# T-Test Results:
# T-Statistic: -13.344225001800195
# P-Value: 1.0113519623975626e-39

# %%
group_0 = df[df['Class'] == 0]['Energy']
group_1 = df[df['Class'] == 1]['Energy']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 0.3050613505866636
#
# Group 1:
# 0.0807356799164781
#
# T-Test Results:
# T-Statistic: 104.46778550173438
# P-Value: 0.0

# %%
group_0 = df[df['Class'] == 0]['ASM']
group_1 = df[df['Class'] == 1]['ASM']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 0.09840048284307537
#
# Group 1:
# 0.00950531141160603
#
# T-Test Results:
# T-Statistic: 71.31638787315163
# P-Value: 0.0

# %%
group_0 = df[df['Class'] == 0]['Homogeneity']
group_1 = df[df['Class'] == 1]['Homogeneity']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 0.5767914301652718
#
# Group 1:
# 0.3587618538703674
#
# T-Test Results:
# T-Statistic: 97.91710001276066
# P-Value: 0.0

# %%
group_0 = df[df['Class'] == 0]['Dissimilarity']
group_1 = df[df['Class'] == 1]['Dissimilarity']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 3.772535878870997
#
# Group 1:
# 5.842332507819351
#
# T-Test Results:
# T-Statistic: -41.05185294217271
# P-Value: 1.0178460618567029e-304

# %%
group_0 = df[df['Class'] == 0]['Correlation']
group_1 = df[df['Class'] == 1]['Correlation']
average_group_0 = group_0.mean()
average_group_1 = group_1.mean()
t_statistic, p_value = ttest_ind(group_0, group_1)
print("Averages:")
print("Group 0:")
print(average_group_0)
print("\nGroup 1:")
print(average_group_1)
print("\nT-Test Results:")
print(f'T-Statistic: {t_statistic}')
print(f'P-Value: {p_value}')
# Out:
# Averages:
# Group 0:
# 0.9583222375769497
#
# Group 1:
# 0.9526099311886724
#
# T-Test Results:
# T-Statistic: 6.698927239128512
# P-Value: 2.4119633017830264e-11

# %%
results_df = pd.DataFrame(columns=['Feature', 'T-Statistic', 'P-Value'])

# %%
results_list = []

features = ['Mean', 'Variance', 'Standard Deviation', 'Entropy', 'Skewness', 'Kurtosis',
            'Contrast', 'Energy', 'ASM', 'Homogeneity', 'Dissimilarity', 'Correlation']

group_0 = df[df['Class'] == 0]
group_1 = df[df['Class'] == 1]

for feature in features:
    t_statistic, p_value = ttest_ind(group_0[feature], group_1[feature])
    average_group_0 = group_0[feature].mean()
    average_group_1 = group_1[feature].mean()

    results_list.append({
        'Feature': feature,
        'T-Statistic': t_statistic,
        'P-Value': p_value,
        'Average_Group_0': average_group_0,
        'Average_Group_1': average_group_1
    })

results_df = pd.DataFrame(results_list)
results_df
# Out:
#                Feature  T-Statistic        P-Value  Average_Group_0  \
# 0                 Mean     5.897080   4.025986e-09         9.982184
# 1             Variance   -19.909534   6.167900e-84       581.230442
# 2   Standard Deviation   -18.271584   1.593279e-71        22.928336
# 3              Entropy    75.977694   0.000000e+00         0.122795
# 4             Skewness   -26.972737  1.225670e-146         3.175090
# 5             Kurtosis   -15.149152   2.288750e-50        12.212278
# 6             Contrast   -13.344225   1.011352e-39       107.014482
# 7               Energy   104.467786   0.000000e+00         0.305061
# 8                  ASM    71.316388   0.000000e+00         0.098400
# 9          Homogeneity    97.917100   0.000000e+00         0.576791
# 10       Dissimilarity   -41.051853  1.017846e-304         3.772536
# 11         Correlation     6.698927   2.411963e-11         0.958322
#
#     Average_Group_1
# 0          8.879527
# 1        871.529477
# ...

# %%
results_df.to_csv('t_test_results.csv', index=False)
